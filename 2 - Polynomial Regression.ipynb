# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# Polynomial Regression is a form of linear regression in which the relationship between the independent variable x and dependent variable y is modeled as an nth degree polynomial. Polynomial regression fits a nonlinear relationship between the value of x and the corresponding conditional mean of y, denoted E(y |x)

# %%
# %matplotlib inline

#input pandas to read csv
import pandas as pd

#input numpy to calculate scientific equations
import numpy as np

from pylab import *

# %%
#import to deal with various types of io
import io

#read csv file
a = pd.read_csv('C:/ML - L00151073/polynomial.csv')    

#assign values of
b = a.speed

#assign values
c = a.distance

#scatter points on graphs
scatter(b,c)      
            
#show graph    
plt.show()

# %%
#ahow the number of elements in speed and distanc column
x = np.array(a.speed)
y = np.array(a.distance)

#define polynomial function with least swaure polynomial fit
p = np.poly1d(np.polyfit(x, y, 4))

# %%
import matplotlib.pyplot as plt

#returns number of spaces evenly with respect to interval
rs = np.linspace(0, 100) 

#plot graphs
plt.scatter(x, y)
plt.plot(rs, p(rs), c='black')
plt.show()

# %%
from sklearn.metrics import r2_score

#regression score function
r2 = r2_score(y, p(x))

print(r2)
# Out:
# 0.9928313149295753
